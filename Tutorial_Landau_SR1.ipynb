# %%
import GEMVAE

# %%
import pandas as pd
import numpy as np
import scanpy as sc
import matplotlib.pyplot as plt
import os
import sys
import warnings
warnings.filterwarnings("ignore")

# %%
gdata = sc.read_h5ad('./data/Landau/spleen_rep_1/Mouse_Spleen/adata_RNA.h5ad')
gdata.var_names_make_unique()
gdata
# Out:
# AnnData object with n_obs × n_vars = 2653 × 32285
#     var: 'gene_ids', 'feature_types', 'genome'
#     obsm: 'spatial'

# %%
pdata = sc.read_h5ad('./data/Landau/spleen_rep_1/Mouse_Spleen/adata_Pro.h5ad')
pdata.var_names_make_unique()
pdata
# Out:
# AnnData object with n_obs × n_vars = 2653 × 21
#     obsm: 'spatial'

# %%
# gdata.obsm=adata.obsm
# gdata.uns = adata.uns
# pdata.obsm=adata.obsm
# pdata.uns = adata.uns

# %%
#Normalization Gene
sc.pp.highly_variable_genes(gdata, flavor="seurat_v3", n_top_genes=3000)
sc.pp.normalize_total(gdata, target_sum=1e4)
sc.pp.log1p(gdata)

#Normalization Protein 
#sc.pp.highly_variable_genes(adata, flavor="seurat_v3", n_top_genes=3000)
#sc.pp.normalize_total(pdata, target_sum=1e4)
sc.pp.log1p(pdata)

# %%
GEMVAE.Cal_Spatial_Net(gdata, rad_cutoff=2)
GEMVAE.Stats_Spatial_Net(gdata)
# Out:
# ------Calculating spatial graph...
# The graph contains 20534 edges, 2653 cells.
# 7.7399 neighbors per cell on average.

# %%
GEMVAE.Cal_Spatial_Net(pdata, rad_cutoff=2)
GEMVAE.Stats_Spatial_Net(pdata)
# Out:
# ------Calculating spatial graph...
# The graph contains 20534 edges, 2653 cells.
# 7.7399 neighbors per cell on average.

# %%
# hyper parameters 
epochs = 400
hidden_dims_gene = [512,30]
hidden_dims_pro = [128, 30]

#cell-type aware params
alpha = 0.45
pre_resolution_gene = 0.55
pre_resolution_pro = 0.25
save_loss = True

# Loss weights
kl_loss = 0
contrastive_loss = 10
weight_decay_loss = 1      #Loss for Ateentions Layers
recon_loss_type = 'ZINB'      # ZINB or MSE
recon_loss = 1

# %%
trained_gdata = GEMVAE.train_GEMVAE(gdata,pdata,n_epochs=epochs,hidden_dims1=hidden_dims_gene,hidden_dims2=hidden_dims_pro,
                                    alpha=alpha,pre_resolution1=pre_resolution_gene,pre_resolution2=pre_resolution_pro, save_loss=save_loss,
                                    kl_loss = kl_loss,
                                    contrastive_loss = contrastive_loss,
                                    weight_decay_loss = weight_decay_loss,       
                                    recon_loss_type = recon_loss_type,   
                                    recon_loss = recon_loss)
# Out:
# Size of Input for gene data :  (2653, 3000)
# Size of Input for protein data :  (2653, 21)
# WARNING:tensorflow:From C:\Users\KARAN\AppData\Roaming\Python\Python39\site-packages\keras\layers\normalization\batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\KARAN\AppData\Roaming\Python\Python39\site-packages\tensorflow\python\util\dispatch.py:1176: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# Loss weights are =  10 1 1 0
# START TRAIN
# ------Pre-clustering Genes using louvain with resolution=0.55
# ------Pre-clustering Protein using louvain with resolution=0.25
# ------Pruning the graph...
# 20534 edges before pruning.
# 15600 edges after pruning.
# ------Pruning the graph...
# 20534 edges before pruning.
# 14426 edges after pruning.
# Epoch: 0, Contrastive Loss: 10.0440, Loss: 4524.7642
# Epoch: 1, Contrastive Loss: 9.4249, Loss: 4509.1025
# Epoch: 2, Contrastive Loss: 9.0103, Loss: 4496.8545
# Epoch: 3, Contrastive Loss: 8.8149, Loss: 4504.3965
# Epoch: 4, Contrastive Loss: 8.7374, Loss: 4495.4233
# Epoch: 5, Contrastive Loss: 8.7116, Loss: 4491.0576
# Epoch: 6, Contrastive Loss: 8.7099, Loss: 4481.5820
# Epoch: 7, Contrastive Loss: 8.7201, Loss: 4466.7368
# Epoch: 8, Contrastive Loss: 8.7358, Loss: 4474.9468
# Epoch: 9, Contrastive Loss: 8.7533, Loss: 4462.5908
# Epoch: 10, Contrastive Loss: 8.7706, Loss: 4443.1157
# Epoch: 11, Contrastive Loss: 8.7862, Loss: 4446.2188
# Epoch: 12, Contrastive Loss: 8.8000, Loss: 4426.6133
# Epoch: 13, Contrastive Loss: 8.8116, Loss: 4410.1807
# Epoch: 14, Contrastive Loss: 8.8211, Loss: 4408.8604
# Epoch: 15, Contrastive Loss: 8.8287, Loss: 4393.7676
# Epoch: 16, Contrastive Loss: 8.8344, Loss: 4385.3599
# Epoch: 17, Contrastive Loss: 8.8387, Loss: 4369.0977
# Epoch: 18, Contrastive Loss: 8.8414, Loss: 4363.4629
# Epoch: 19, Contrastive Loss: 8.8427, Loss: 4345.4175
# Epoch: 20, Contrastive Loss: 8.8428, Loss: 4338.6445
# Epoch: 21, Contrastive Loss: 8.8415, Loss: 4327.7729
# Epoch: 22, Contrastive Loss: 8.8392, Loss: 4308.8057
# Epoch: 23, Contrastive Loss: 8.8357, Loss: 4292.6323
# Epoch: 24, Contrastive Loss: 8.8313, Loss: 4286.2266
# Epoch: 25, Contrastive Loss: 8.8259, Loss: 4278.4429
# Epoch: 26, Contrastive Loss: 8.8197, Loss: 4263.4102
# Epoch: 27, Contrastive Loss: 8.8127, Loss: 4251.4131
# Epoch: 28, Contrastive Loss: 8.8051, Loss: 4247.4331
# Epoch: 29, Contrastive Loss: 8.7969, Loss: 4238.3540
# Epoch: 30, Contrastive Loss: 8.7883, Loss: 4228.5454
# Epoch: 31, Contrastive Loss: 8.7794, Loss: 4220.4707
# Epoch: 32, Contrastive Loss: 8.7704, Loss: 4215.5122
# Epoch: 33, Contrastive Loss: 8.7612, Loss: 4207.4946
# Epoch: 34, Contrastive Loss: 8.7520, Loss: 4202.5679
# Epoch: 35, Contrastive Loss: 8.7429, Loss: 4202.8901
# Epoch: 36, Contrastive Loss: 8.7340, Loss: 4196.9805
# Epoch: 37, Contrastive Loss: 8.7253, Loss: 4186.5825
# Epoch: 38, Contrastive Loss: 8.7169, Loss: 4187.4307
# Epoch: 39, Contrastive Loss: 8.7089, Loss: 4184.5210
# Epoch: 40, Contrastive Loss: 8.7012, Loss: 4181.9321
# Epoch: 41, Contrastive Loss: 8.6939, Loss: 4180.8833
# Epoch: 42, Contrastive Loss: 8.6870, Loss: 4171.8555
# Epoch: 43, Contrastive Loss: 8.6804, Loss: 4166.6323
# Epoch: 44, Contrastive Loss: 8.6742, Loss: 4168.4062
# Epoch: 45, Contrastive Loss: 8.6684, Loss: 4172.5024
# Epoch: 360, Contrastive Loss: 8.1436, Loss: 4139.2417
# Epoch: 361, Contrastive Loss: 8.1222, Loss: 4144.9971
# Epoch: 362, Contrastive Loss: 8.1088, Loss: 4141.2373
# Epoch: 363, Contrastive Loss: 8.0954, Loss: 4139.8628
# Epoch: 364, Contrastive Loss: 8.0899, Loss: 4142.3276
# Epoch: 365, Contrastive Loss: 8.0866, Loss: 4139.9844
# Epoch: 366, Contrastive Loss: 8.0794, Loss: 4145.2915
# Epoch: 367, Contrastive Loss: 8.0747, Loss: 4139.1362
# Epoch: 368, Contrastive Loss: 8.0687, Loss: 4145.4370
# Epoch: 369, Contrastive Loss: 8.0597, Loss: 4149.2271
# Epoch: 370, Contrastive Loss: 8.0496, Loss: 4145.0771
# Epoch: 371, Contrastive Loss: 8.0457, Loss: 4134.5435
# Epoch: 372, Contrastive Loss: 8.0295, Loss: 4142.9907
# Epoch: 373, Contrastive Loss: 8.0210, Loss: 4146.8389
# Epoch: 374, Contrastive Loss: 8.0320, Loss: 4136.9966
# Epoch: 375, Contrastive Loss: 8.0091, Loss: 4139.9546
# Epoch: 376, Contrastive Loss: 8.0712, Loss: 4138.3823
# Epoch: 377, Contrastive Loss: 8.0796, Loss: 4146.4385
# Epoch: 378, Contrastive Loss: 7.9990, Loss: 4139.8374
# Epoch: 379, Contrastive Loss: 8.1212, Loss: 4151.2441
# Epoch: 380, Contrastive Loss: 8.2020, Loss: 4134.4443
# Epoch: 381, Contrastive Loss: 8.0951, Loss: 4149.5254
# Epoch: 382, Contrastive Loss: 7.9842, Loss: 4133.1006
# Epoch: 383, Contrastive Loss: 8.0257, Loss: 4134.0488
# Epoch: 384, Contrastive Loss: 8.0039, Loss: 4146.9976
# Epoch: 385, Contrastive Loss: 7.9788, Loss: 4144.6758
# Epoch: 386, Contrastive Loss: 7.9841, Loss: 4150.9248
# Epoch: 387, Contrastive Loss: 7.9615, Loss: 4138.4346
# Epoch: 388, Contrastive Loss: 7.9543, Loss: 4142.2832
# Epoch: 389, Contrastive Loss: 7.9645, Loss: 4133.0615
# Epoch: 390, Contrastive Loss: 7.9448, Loss: 4138.1968
# Epoch: 391, Contrastive Loss: 7.9913, Loss: 4138.7461
# Epoch: 392, Contrastive Loss: 7.9809, Loss: 4136.5459
# Epoch: 393, Contrastive Loss: 7.9467, Loss: 4141.4409
# Epoch: 394, Contrastive Loss: 7.9453, Loss: 4139.4702
# Epoch: 395, Contrastive Loss: 7.9519, Loss: 4141.3018
# Epoch: 396, Contrastive Loss: 7.9418, Loss: 4137.9453
# Epoch: 397, Contrastive Loss: 7.9569, Loss: 4135.5273
# Epoch: 398, Contrastive Loss: 7.9501, Loss: 4138.7305
# Epoch: 399, Contrastive Loss: 7.9284, Loss: 4134.7896

# %%
plt.plot(trained_gdata.uns['arch_loss'])
plt.show()

# %%
os.environ["R_HOME"] = r"C:\Program Files\R\R-4.3.0"
os.environ["PATH"]   = r"C:\Program Files\R\R-4.3.0\bin\x64" + ";" + os.environ["PATH"]

# %%
#DEFINE THE NUMBER OF CLUSTERS HERE
n_clusters = 6

# %%
for tool in ['mclust','leiden','louvain']:
   # we use mcluster as clustering tool by default.
   print("Using tool : ",tool)

   # performing PCA
   gdata.obsm['emb_combined_pca'] = sc.tl.pca(gdata.obsm['MY_ARCH'])

   # clustering
   if tool == 'mclust':
      GEMVAE.clustering(gdata, key='emb_combined_pca', add_key='1', n_clusters=n_clusters, method=tool)
   elif tool in ['leiden']:
      GEMVAE.clustering(gdata, key='emb_combined_pca', add_key='2', n_clusters=n_clusters, method=tool, start=0.01, end=1.3, increment=0.04)
   elif tool in ['louvain']:
      GEMVAE.clustering(gdata, key='emb_combined_pca', add_key='3', n_clusters=n_clusters, method=tool, start=0.01, end=1.3, increment=0.04)
# Out:
# Using tool :  mclust
# R[write to console]:                    __           __
#    ____ ___  _____/ /_  _______/ /_
#   / __ `__ \/ ___/ / / / / ___/ __/
#  / / / / / / /__/ / /_/ (__  ) /_
# /_/ /_/ /_/\___/_/\__,_/____/\__/   version 6.0.0
# Type 'citation("mclust")' for citing this R package in publications.
# fitting ...
#   |======================================================================| 100%
# Using tool :  leiden
# Searching resolution...
# resolution=1.29, cluster number=8
# resolution=1.25, cluster number=8
# resolution=1.21, cluster number=8
# resolution=1.17, cluster number=8
# resolution=1.1300000000000001, cluster number=8
# resolution=1.09, cluster number=8
# resolution=1.05, cluster number=8
# resolution=1.01, cluster number=8
# resolution=0.97, cluster number=7
# resolution=0.93, cluster number=7
# resolution=0.89, cluster number=7
# resolution=0.85, cluster number=7
# resolution=0.81, cluster number=7
# resolution=0.77, cluster number=7
# resolution=0.73, cluster number=5
# resolution=0.6900000000000001, cluster number=6
# Using tool :  louvain
# Searching resolution...
# resolution=1.29, cluster number=8
# resolution=1.25, cluster number=7
# resolution=1.21, cluster number=8
# resolution=1.17, cluster number=7
# resolution=1.1300000000000001, cluster number=7
# resolution=1.09, cluster number=6

# %% [markdown]
# Visualizing the clusters

# %%
# visualization Mclust
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='1', ax=ax_list[0], title='mclust', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='1', ax=ax_list[1], title='mclust', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()

# %%
# visualization leiden
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='2', ax=ax_list[0], title='leiden', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='2', ax=ax_list[1], title='leiden', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()

# %%
# visualization louven
fig, ax_list = plt.subplots(1, 2, figsize=(12, 5))
sc.pp.neighbors(gdata, use_rep='emb_combined_pca', n_neighbors=10)
sc.tl.umap(gdata)

sc.pl.umap(gdata, color='3', ax=ax_list[0], title='louvain', s=60, show=False)
sc.pl.embedding(gdata, basis='spatial', color='3', ax=ax_list[1], title='louvain', s=90, show=False)

plt.tight_layout(w_pad=0.3)
plt.show()
